# %% [markdown]
# # TAREA DE EJERCICIO
#
# Actualiza el proyecto del día 1 para resumir una página web y utilizar un modelo de código abierto que se ejecute localmente a través de Ollama en lugar de OpenAI
#
# Podrás utilizar esta técnica para todos los proyectos posteriores si prefiere no utilizar API de pago (closed source).
#
# **Beneficios:**
# 1. Sin cargos por API: código abierto
# 2. Los datos no salen de su ordenador
#
# **Desventajas:**
# 1. Tiene mucha menos potencia (parámetros) que el modelo Frontier
#
# ## Resumen de la instalación de Ollama
#
# ¡Simplemente visita [ollama.com](https://ollama.com) e instálalo!
#
# Una vez que hayas terminado, el servidor ollama ya debería estar ejecutándose localmente.
# Si entras en:
# [http://localhost:11434/](http://localhost:11434/)
#
# Debería ver el mensaje `Ollama se está ejecutando`.
#
# De lo contrario, abre una nueva Terminal (Mac) o Powershell (Windows) e introduce `ollama serve`.
# Luego, intenta entrar em [http://localhost:11434/](http://localhost:11434/) nuevamente.

# %%
# imports

import requests
from bs4 import BeautifulSoup
from IPython.display import Markdown, display

# %%
# Constantes

OLLAMA_API = "http://localhost:11434/api/chat"
HEADERS = {"Content-Type": "application/json"}
MODEL = "llama3.2"

# %%
# Crea una lista de mensajes utilizando el mismo formato que usamos para OpenAI

messages = [
    {"role": "user", "content": "Describe algunas de las aplicaciones comerciales de la IA generativa."}
]

# %%
payload = {
        "model": MODEL,
        "messages": messages,
        "stream": False
    }

# %%
response = requests.post(OLLAMA_API, json=payload, headers=HEADERS)
print(response.json()['message']['content'])
# Out:
# La inteligencia artificial (IA) generativa es un campo emergente que se enfoca en el desarrollo de algoritmos y técnicas para crear contenido original a partir de datos y patrones existentes. A continuación, se presentan algunas de las aplicaciones comerciales más destacadas de la IA generativa:
#
# 1. **Diseño gráfico**: Las herramientas de diseño gráfico como Adobe Fresco y Autodesk Sketchbook utilizan la IA para crear pinceles y herramientas que imitan el comportamiento de los artistas humanos, lo que permite a los diseñadores crear arte original y personalizado.
#
# 2. **Generación de contenido**: La IA generativa se utiliza en plataformas como Medium y WordPress para generar contenido automático, como artículos de blog y noticias, que pueden ser personalizados y adaptados a las necesidades específicas de cada usuario.
#
# 3. **Personalización de productos**: Las empresas como Zara y H&M utilizan la IA generativa para crear diseños de moda personalizados según las preferencias y estilos de los clientes. Esto se logra mediante el uso de datos de comportamiento y estilo de vida de los clientes.
#
# 4. **Creación de música y videojuegos**: La música electrónica y videojuegos son ejemplos clásicos de la aplicación de la IA generativa en la creación de contenido creativo. Las herramientas como Amper Music y AIVA permiten a los compositores crear musicales original utilizando algoritmos de IA.
#
# 5. **Diseño de arquitectura**: La IA generativa se utiliza para diseñar edificios y espacios interiores, lo que permite a los arquitectos y diseñadores explorar nuevas formas y estilos de diseño antes de llevarlos a la vida real.
#
# 6. **Generación de contenido de marketing**: Las empresas utilizan la IA generativa para crear contenido de marketing personalizado, como imágenes y videos, que pueden ser adaptados a las necesidades específicas de cada campaña publicitaria.
#
# 7. **Análisis de datos**: La IA generativa se utiliza en el análisis de datos para identificar patrones y tendencias no visibles a simple vista. Esto permite a las empresas tomar decisiones informadas sobre la estrategia comercial y la toma de riesgos.
#
# 8. **Creación de personajes virtuales**: La IA generativa se utiliza en la creación de personajes virtuales para videojuegos, películas y series de televisión, lo que permite a los creadores personalizar el comportamiento y la apariencia de sus personajes.
#
# 9. **Diseño de productos**: Las empresas como Tesla y BMW utilizan la IA generativa para diseñar productos con características personalizadas y adaptadas a las necesidades específicas de cada cliente.
#
# 10. **Creación de contenido educativo**: La IA generativa se utiliza en la creación de contenido educativo, como videos y juegos interactivos, que pueden ser personalizados según las necesidades de los estudiantes y profesores.
#
# En resumen, la IA generativa tiene un gran potencial para revolucionar la forma en que crean y producen contenido en diversas industrias.

# %% [markdown]
# # Presentación del paquete ollama
#
# Ahora haremos lo mismo, pero utilizando el elegante paquete de Python ollama en lugar de una llamada HTTP directa.
#
# En esencia, se realiza la misma llamada que se indicó anteriormente al servidor ollama que se ejecuta en localhost:11434

# %%
import ollama

response = ollama.chat(model=MODEL, messages=messages)
print(response['message']['content'])
# Out:
# La inteligencia artificial (IA) generativa es una subrama de la inteligencia artificial que se enfoca en crear nuevos elementos a partir de datos existentes, como imágenes, textos o música. A continuación, se presentan algunas de las aplicaciones comerciales más relevantes de la IA generativa:
#
# 1. **Generación de contenido**: La IA generativa se utiliza para crear contenido de alta calidad y personalizado, como imágenes, videos y texto, sin necesidad de intervención humana. Esto puede ser especialmente útil para empresas que necesitan generar contenido en gran cantidad y velocidad.
#
# 2. **Diseño gráfico y visualización**: Los algoritmos de IA generativa pueden crear diseños gráficos innovadores y atractivos, lo que puede ser útil para marcas y empresas que buscan differentiate su imagen y presentación.
#
# 3. **Creación de música y sonidos**: La IA generativa se utiliza para crear música original y sonidos para películas, videojuegos y anuncios comerciales.
#
# 4. **Generación de productos virtuales**: La IA generativa se utiliza para crear modelos 3D y objetos virtuales que pueden ser utilizados en la creación de productos virtuales y experiencias inmersivas.
#
# 5. **Creación de carros de fábrica**: Los algoritmos de IA generativa se utilizan para crear modelos de vehículos, lo que puede ayudar a las empresas a reducir los costos y tiempos de desarrollo en la creación de nuevos productos.
#
# 6. **Generación de contenido de marketing**: La IA generativa se utiliza para crear contenido de marketing personalizado, como anuncios y materiales promocionales, que pueden ser ajustados según el comportamiento del cliente.
#
# 7. **Creación de experiencias inmersivas**: Los algoritmos de IA generativa se utilizan para crear experiencias inmersivas en realidad aumentada y virtual, lo que puede ser especialmente útil para industrias como la educación y la atención sanitaria.
#
# 8. **Generación de datos**: La IA generativa se utiliza para generar datos simulados que pueden ser utilizados en experimentos científicos y análisis de datos.
#
# 9. **Creación de productos personalizados**: Los algoritmos de IA generativa se utilizan para crear productos personalizados según las preferencias y necesidades del cliente, lo que puede ayudar a las empresas a aumentar la satisfacción del cliente.
#
# 10. **Optimización de procesos**: La IA generativa se utiliza para optimizar procesos empresariales, como la producción y el transporte, mediante la creación de modelos predictivos y simulaciones de escenarios.
#
# En resumen, la IA generativa tiene una amplia gama de aplicaciones comerciales que pueden ser utilizadas para mejorar la eficiencia, la innovación y la experiencia del cliente.

# %% [markdown]
# # AHORA el ejercicio para ti
#
# Toma el código del día 1 e incorpóralo aquí para crear un resumidor de sitios web que use Llama 3.2 ejecutándose localmente en lugar de OpenAI

# %%
import requests
from bs4 import BeautifulSoup
from IPython.display import Markdown, display

# %%
# Una clase para representar una página web
# Si no estás familiarizado con las clases, consulta el cuaderno "Python intermedio"

class Website:
    """
    Una clase de utilidad para representar un sitio web que hemos scrappeado
    """

    def __init__(self, url):
        """
        Crea este objeto de sitio web a partir de la URL indicada utilizando la biblioteca BeautifulSoup
        """
        self.url = url
        response = requests.get(url)
        soup = BeautifulSoup(response.content, 'html.parser')
        self.title = soup.title.string if soup.title else "No tiene título"
        for irrelevant in soup.body(["script", "style", "img", "input"]):
            irrelevant.decompose()
        self.text = soup.body.get_text(separator="\n", strip=True)

# %%
frog = Website("https://medium.com/@borandabak/0-to-70-000-freelance-journey-5b442fb8231c")
print(frog.title)
print(frog.text)
# Out:
# 0$ to 70.000$ Freelance Journey. Hello Everyone,
# In this article, I’ll… | by borandabak | Medium
# Open in app
# Sign up
# Sign in
# Write
# Sign up
# Sign in
# Home
# Following
# Library
# Your lists
# Saved lists
# Highlights
# Reading history
# Stories
# Stats
# 0$ to 70.000$ Freelance Journey
# borandabak
# ·
# Follow
# 2 min read
# ·
# Jan 20, 2025
# --
# 2
# Listen
# Share
# Hello Everyone,
# In this article, I’ll share how I became a successful freelancer completing projects for clients around the world, despite not having a degree or prior experience in software development.
# The First Step
# I started my journey into software development during the pandemic, in May 2020. I began learning by watching YouTube videos at home. From a young age, I was always curious, and being stuck at home was the perfect opportunity to explore this interest. Before this, I was just an ordinary person aspiring to become a professional basketball player.
# While I didn’t achieve that dream, sports taught me the value of professionalism and discipline — traits that helped me progress quickly in software development. I decided to focus on data science because I loved strategy and problem-solving. I dove into YouTube tutorials and courses on platforms like Coursera and began working on my own projects.
# Discovering Freelancing
# I’ve always been drawn to freedom, which made freelancing a natural choice for me. The idea of working on global projects and building an international reputation was incredibly appealing. During my research into freelancing platforms, I discovered
# Upwork
# . While other platforms seemed fine, it was clear that Upwork had the largest and most active community.
# However, my freelancing journey didn’t start smoothly. For the first
# 40 days
# , I couldn’t land a single project. Financially, it was tough because I couldn’t afford to apply for many jobs. But on the 40th day, I secured my first job — a project that marked the beginning of everything.
# Since I didn’t have prior experience working with a company, I faced some challenges. During this period, I focused on improving both my technical skills and English communication abilities.
# Breakthrough and Growth
# Toward the end of each year, I dedicate the final three months to research and development, planning for the year ahead, and learning new technologies. In December 2023, I realized that
# 2024 would be the year of Generative AI.
# I focused on mastering this technology and even developed my own framework. When I presented it to companies, they were impressed, which helped me generate over
# $60,000
# in revenue in 2024. For 2025, I’ve set a goal to reach
# $200,000
# , and I’m optimistic that I can achieve it.
# Key Takeaways
# Here are some lessons I’ve learned from my freelancing journey:
# Freelancing is tough.
# Patience is essential.
# Choose a
# niche area
# in your field and build a quality portfolio.
# Learn to communicate with a
# professional tone.
# Experiment every day and learn from your mistakes — success in freelancing is impossible without this mindset.
# I hope my story inspires you. If you have any
# AI projects
# , feel free to reach out to me using the link below. Let’s bring your vision to life!
# https://www.upwork.com/services/consultation/development-it-boran-oktay-1736217291062976512
# Freelance
# AI
# Upwork
# Python
# Data
# --
# --
# 2
# Follow
# Written by
# borandabak
# 471 Followers
# ·
# 24 Following
# Data Scientist | Data Analyst | Software Developer
# https://www.linkedin.com/in/boran-oktay-dabak-5377bb176/
# https://www.upwork.com/freelancers/boranoktaydabak
# Follow
# Responses (
# 2
# )
# See all responses
# Help
# Status
# About
# Careers
# Press
# Blog
# Privacy
# Rules
# Terms
# Text to speech

# %%
def user_prompt_for(website):
    user_prompt = f"Estás viendo un sitio web titulado {website.title}"
    user_prompt += "\nEl contenido de este sitio web es el siguiente; \
    proporciona un breve resumen de este sitio web en formato Markdown. \
    Si incluye noticias, productos o anuncios, resúmelos también.\n\n"
    user_prompt += website.text
    return user_prompt

# %%
messages2 = [
    {"role": "user", "content": user_prompt_for(frog)}
]
response = ollama.chat(model=MODEL, messages=messages2)
print(response['message']['content'])
# Out:
# **Resumen del sitio web "0$ to 70.000$ Freelance Journey"**
#
# El sitio web "0$ to 70.000$ Freelance Journey" es una publicación de Medium que comparte la experiencia del autor, Boran Bak, en su viaje como freelancer de software desarrollo y data scientist.
#
# **Resumen del artículo**
#
# El autor comienza explicando cómo comenzó a aprender software development durante la pandemia de 2020, después de haber abandonado su sueño de convertirse en jugador profesional de baloncesto. Descubre que la curiosidad y la disciplina le ayudaron a avanzar rápidamente en el campo.
#
# El autor comparte cómo descubrió freelancing y eligió a Upwork como plataforma para encontrar trabajos, aunque no comenzó su carrera fácilmente y tuvo dificultades para obtener proyectos. Sin embargo, después de 40 días, logró su primer proyecto, lo que marcó el comienzo de su carrera como freelancer.
#
# El autor también comparte cómo se enfocó en mejorar sus habilidades técnicas y comunicación en inglés, y cómo este esfuerzo le ayudó a alcanzar un ingreso de $60.000 en 2024 y un objetivo de alcanzar $200.000 en 2025.
#
# **Noticias, productos o anuncios**
#
# - La publicación incluye una oferta de consultoría para proyectos de AI en Upwork.
# - El autor comparte su experiencia como freelancer y ofrece consejos para aquellos que buscan seguir su ejemplo.
# - Se menciona la plataforma de freelancing Upwork como opción para encontrar trabajos.
#
# **Palabras clave**
#
# - Freelance
# - Software desarrollo
# - Data scientist
# - Data analysis
# - AI
# - Generative AI
# - Upwork
